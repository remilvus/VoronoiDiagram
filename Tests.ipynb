# %%
from MaxMetric import *
from Plot import *
import numpy as np

# %matplotlib notebook

# %% [markdown]
# Max metric test

# %%
# %matplotlib notebook
a = [0.4, 0.7]
b = [0.3, 0.65]
bis = bisector(a, b)
print(bis)
points = PointsCollection([a, b])
lines = LinesCollection(bis)
scenes=[Scene([points], [lines])]
plot = Plot(scenes)
plot.draw()
# Out:
# [[[0.050000000000000044, 1], [0.35, 0.7000000000000001]], [[0.35, 0.7000000000000001], [0.35, 0.6499999999999999]], [[0.35, 0.6499999999999999], [0.9999999999999999, 0]]]
# <img src="data:image/png;base64,..." width="639.4833333333333">

# %%
a = [0.4, 0.7]
b = [0.5, 0.5]
bis = bisector(a, b)
points = PointsCollection([a, b])
lines = LinesCollection(bis)
scenes=[Scene([points], [lines])]
plot = Plot(scenes)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="639.4833333333333">

# %% [markdown]
# Line extraction tests

# %%
    def extract_line_part(line, a, b, eps=10**-5):
        # todo extract part of line between points a and b
        # Let me try
        newline=[]
        i=0
        for each in line:
            if a[0] >= each[1][0] - eps:
                i+=1
            elif b[0] > each[1][0]-eps:
                newline.append([a, each[1]])
                a = each[1]
            else: break
        newline.append([a, b])
        return newline

# %%
a = [0.31, 0.65]
b = [0.71, 0.]
bis = bisector(a, b)
points = PointsCollection([a, b])
lines = LinesCollection(bis)
scenes=[Scene([points], [lines])]
plot = Plot(scenes)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="639.4833333333333">

# %%
print(bis)
print(extract_line_part(bis, (0.06, 0.06), (0.56, 0.52))) # makes only 2 segments (should make 3)
# Out:
# [[[0, 0.19999999999999996], [0.4, 0.6]], [[0.4, 0.6], [0.5, 0.6]], [[0.5, 0.6], [0.9, 1]]]
# [[(0.06, 0.06), [0.4, 0.6]], [[0.4, 0.6], [0.5, 0.6]], [[0.5, 0.6], (0.56, 0.52)]]

# %%
print(bis)
print(extract_line_part(bis, bis[0][0], bis[-1][-1])) # last segment contains the same point twice
# Out:
# [[[0.05999999999999994, 0], [0.51, 0.45000000000000007]], [[0.51, 0.45000000000000007], [0.51, 0.48]], [[0.51, 0.48], [1, 0.97]]]
# [[[0.05999999999999994, 0], [0.51, 0.45000000000000007]], [[0.51, 0.45000000000000007], [1, 0.97]], [[1, 0.97], [1, 0.97]]]
