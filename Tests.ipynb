# %%
from MaxMetric import *
from Plot import *
import numpy as np

# %matplotlib notebook

# %% [markdown]
# Max metric test

# %%
# %matplotlib notebook
a = [0.4, 0.7]
b = [0.3, 0.65]
bis = bisector(a, b)
print(bis)
points = PointsCollection([a, b])
lines = LinesCollection(bis)
scenes=[Scene([points], [lines])]
plot = Plot(scenes)
plot.draw()
# Out:
# [[[0.050000000000000044, 1], [0.35, 0.7000000000000001]], [[0.35, 0.7000000000000001], [0.35, 0.6499999999999999]], [[0.35, 0.6499999999999999], [0.9999999999999999, 0]]]
# <img src="data:image/png;base64,..." width="639.4833333333333">

# %%
a = [0.4, 0.7]
b = [0.5, 0.5]
bis = bisector(a, b)
points = PointsCollection([a, b])
lines = LinesCollection(bis)
scenes=[Scene([points], [lines])]
plot = Plot(scenes)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# Line extraction tests

# %%
    def extract_line_part(line, a, b, eps=10**-5):
        # todo extract part of line between points a and b
        # Let me try
        newline=[]
        i=0
        for each in line:
            if a[0] >= each[1][0] - eps:
                i+=1
            elif b[0] > each[1][0]-eps:
                newline.append([a, each[1]])
                a = each[1]
            else: break
        newline.append([a, b])
        return newline

# %%
a = [0.31, 0.65]
b = [0.71, 0.]
bis = bisector(a, b)
points = PointsCollection([a, b])
lines = LinesCollection(bis)
scenes=[Scene([points], [lines])]
plot = Plot(scenes)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
print(bis)
print(extract_line_part(bis, (0.06, 0.06), (0.56, 0.52))) # makes only 2 segments (should make 3)
# Out:
# [[[0.05999999999999994, 0], [0.38499999999999995, 0.325]], [[0.38499999999999995, 0.325], [0.635, 0.325]], [[0.635, 0.325], [1, 0.69]]]
# [[(0.06, 0.06), [0.38499999999999995, 0.325]], [[0.38499999999999995, 0.325], (0.56, 0.52)]]

# %%
print(bis)
print(extract_line_part(bis, bis[0][0], bis[-1][-1])) # last segment contains the same point twice
# Out:
# [[[0.05999999999999994, 0], [0.38499999999999995, 0.325]], [[0.38499999999999995, 0.325], [0.635, 0.325]], [[0.635, 0.325], [1, 0.69]]]
# [[[0.05999999999999994, 0], [0.38499999999999995, 0.325]], [[0.38499999999999995, 0.325], [0.635, 0.325]], [[0.635, 0.325], [1, 0.69]], [[1, 0.69], [1, 0.69]]]

# %%
a = [0.37, 0.72]
b = [0.68, 0.83]
bis = bisector(a, b)
points = PointsCollection([a, b])
lines = LinesCollection(bis)
scenes=[Scene([points], [lines])]
plot = Plot(scenes)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="639.4833333333333">

# %%
part = extract_line_part(bis, (0.525, 0.875), (0.59, 0.60))
print(bis)
print(part)
# Out:
# [[[0.4, 1], [0.525, 0.875]], [[0.525, 0.875], [0.525, 0.6749999999999999]], [[0.525, 0.6749999999999999], [1, 0.19999999999999996]]]
# [[(0.525, 0.875), (0.59, 0.6)]]

# %%
a = [0.37, 0.72]
b = [0.68, 0.83]
bis = bisector(a, b)
points = PointsCollection([a, b])
extract_points = PointsCollection([(0.525, 0.875), (0.59, 0.60)], color='red')
lines = LinesCollection(bis + part)
scenes=[Scene([points, extract_points], [lines])]
plot = Plot(scenes)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="639.4833333333333">

# %% [markdown]
# two intersections

# %%
a1 = [0.24, 0.7]
b1 = [0.75, 0.25]
bis1 = bisector(a1, b1)
a2 = [0.2, 0.6]
b2 = [0.8, 0.3]
bis2 = bisector(a2, b2)
points = [PointsCollection([a1, b1]), PointsCollection([a2, b2], color='orange')]
bis3 = bisector(a1, a2)
bis4 = bisector(b1, b2)
bis5 = bisector(a1, b2)
bis6 = bisector(a2, b1)
lines = [LinesCollection(bis1), LinesCollection(bis2, color='orange'), 
         LinesCollection(bis3, color='black'), LinesCollection(bis4, color='black')]#,
        #LinesCollection(bis5, color='green'), LinesCollection(bis6, color='green')]
scenes=[Scene(points, lines)]
plot = Plot(scenes)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="639.4833333333333">
